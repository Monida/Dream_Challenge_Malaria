# %% [markdown]
# # Try different models

# %% [markdown]
# This jupyter notebook is dedicated to training and evaluating different models

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Open and view all the files

# %%
train=pd.read_csv('../data/flat_train.csv',index_col=0)
test=pd.read_csv('../data/flat_test.csv',index_col=0)
IC50=pd.read_csv('../data/flat_IC50.csv',index_col=0)
isolates_list = [line.rstrip('\n') for line in open('../data/isolates.txt')]
isolates_list_test = [line.rstrip('\n') for line in open('../data/isolates_test.txt')]
genes_column_labels_df=pd.read_csv('../data/genes_column_labels.csv',index_col=0)
genes_list = [line.rstrip('\n') for line in open('../data/genes_to_keep.txt')]

# %%
train.head()
# Out:
#             PF3D7_1360200_24HR_DHA  PF3D7_1360200_24HR_UT  \
# isolate_01               -1.237558               0.196928
# isolate_02               -0.398779              -0.374733
# isolate_03               -0.277068              -0.954536
# isolate_04                0.140547              -0.054547
# isolate_05                0.337845              -0.991300
#
#             PF3D7_1360200_6HR_DHA  PF3D7_1360200_6HR_UT  \
# isolate_01              -0.539628              0.232753
# isolate_02               0.015598             -0.385285
# isolate_03               0.144117             -1.065880
# isolate_04              -0.388522             -0.722052
# isolate_05              -0.103856              0.030470
#
#             PF3D7_1212800_24HR_DHA  PF3D7_1212800_24HR_UT  \
# isolate_01                0.631145               0.005077
# isolate_02                0.034129               0.536841
# isolate_03                0.387218               0.556922
# isolate_04               -0.119731              -0.158099
# isolate_05               -0.059112               0.446838
#
#             PF3D7_1212800_6HR_DHA  PF3D7_1212800_6HR_UT  \
# isolate_01               0.451263              0.080951
# isolate_02               0.156295              0.431583
# isolate_03               0.230177              0.444599
# isolate_04               0.466390              0.673041
# isolate_05               0.164930             -0.134692
#
#             PF3D7_1234600_24HR_DHA  PF3D7_1234600_24HR_UT  ...  \
# isolate_01                0.432115              -0.406583  ...
# isolate_02               -0.359269              -0.187211  ...
# isolate_03                0.202430               0.167307  ...
# isolate_04               -0.465047              -0.738471  ...
# isolate_05               -0.797104               0.297453  ...
#
#             PF3D7_0618500_DHA_UT_6HR  PF3D7_0618500_DHA_UT_24HR  \
# isolate_01                  0.571128                   0.564089
# isolate_02                 -0.023408                  -0.688128
# isolate_03                 -1.236190                  -0.663151
# isolate_04                  0.460820                   0.578757
# isolate_05                  0.695048                  -0.797551
#
#             PF3D7_0628200_24HR_6HR_DHA  PF3D7_0628200_24_6HR_UT  \
# isolate_01                   -0.013649                -0.384448
# isolate_02                    0.286911                -0.028067
# isolate_03                    0.129896                -0.026631
# isolate_04                   -0.041681                 0.330944
# isolate_05                    0.268183                -0.000600
#
#             PF3D7_0628200_DHA_UT_6HR  PF3D7_0628200_DHA_UT_24HR  \
# isolate_01                 -0.422965                  -0.052167
# isolate_02                 -0.129251                   0.185726
# isolate_03                  0.066985                   0.223512
# isolate_04                 -0.031242                  -0.403866
# isolate_05                 -0.000899                   0.267883
#
#             PF3D7_1368700_24HR_6HR_DHA  PF3D7_1368700_24_6HR_UT  \
# isolate_01                   -0.330049                -0.132059
# isolate_02                    0.163327                 0.298354
# isolate_03                    0.400941                 0.138671
# isolate_04                   -0.259940                -0.192218
# isolate_05                    0.463178                -0.175036
#
#             PF3D7_1368700_DHA_UT_6HR  PF3D7_1368700_DHA_UT_24HR
# isolate_01                  0.561004                   0.363013
# isolate_02                  0.191827                   0.056801
# isolate_03                  0.331753                   0.594023
# isolate_04                  0.147535                   0.079813
# isolate_05                  0.013171                   0.651385
#
# [5 rows x 3848 columns]

# %%
IC50.head()
# Out:
#             DHA_IC50
# isolate_01     2.177
# isolate_02     1.697
# isolate_03     1.799
# isolate_04     0.710
# isolate_05     2.025

# %%
test.head()
# Out:
#    PF3D7_1360200_24HR_DHA  PF3D7_1360200_24HR_UT  PF3D7_1360200_6HR_DHA  \
# 0               -0.174775              -0.295609              -0.416325
# 1                0.399533               0.146867               0.324318
# 2               -0.176645              -0.544585               0.019547
# 3               -0.417563              -0.403714               0.338701
# 4               -0.479479              -0.105337               0.544339
#
#    PF3D7_1360200_6HR_UT  PF3D7_1212800_24HR_DHA  PF3D7_1212800_24HR_UT  \
# 0              0.298822                0.128111               0.561929
# 1              0.315899                0.066858               0.027401
# 2             -0.417121                0.138302               0.526993
# 3              0.404703                0.301630               0.463055
# 4             -0.924440                0.221467               0.114849
#
#    PF3D7_1212800_6HR_DHA  PF3D7_1212800_6HR_UT  PF3D7_1234600_24HR_DHA  \
# 0               0.345033              0.056966               -0.194875
# 1               0.067937             -0.464352               -0.138635
# 2               0.138940             -0.084193               -0.051677
# 3               0.053077              0.119237               -0.006026
# 4              -0.033903              0.292947                0.130474
#
#    PF3D7_1234600_24HR_UT  ...  PF3D7_0618500_DHA_UT_6HR  \
# 0              -0.170907  ...                  0.344871
# 1              -0.733134  ...                  0.047088
# 2              -0.083284  ...                  0.306211
# 3               0.184238  ...                  1.108617
# 4              -0.274636  ...                 -0.703833
#
#    PF3D7_0618500_DHA_UT_24HR  PF3D7_0628200_24HR_6HR_DHA  \
# 0                  -0.621592                   -0.126831
# 1                   0.380829                    0.172600
# 2                  -0.093699                   -0.119335
# 3                   0.198459                   -0.302420
# 4                   0.573340                   -0.224813
#
#    PF3D7_0628200_24_6HR_UT  PF3D7_0628200_DHA_UT_6HR  \
# 0                -0.194757                 -0.121074
# 1                 0.018954                 -0.089144
# 2                 0.023164                  0.169706
# 3                -0.342440                  0.042755
# 4                 0.068472                  0.060340
#
#    PF3D7_0628200_DHA_UT_24HR  PF3D7_1368700_24HR_6HR_DHA  \
# 0                  -0.053148                   -0.865734
# 1                   0.064502                   -0.213451
# 2                   0.027207                   -0.484834
# 3                   0.082776                    0.251723
# 4                  -0.232946                   -0.898682
#
#    PF3D7_1368700_24_6HR_UT  PF3D7_1368700_DHA_UT_6HR  \
# 0                -0.955845                 -0.291102
# 1                 0.608781                  0.594650
# 2                 0.364730                  0.320544
# 3                -0.637584                 -0.952582
# 4                 0.426429                  0.804087
#
#    PF3D7_1368700_DHA_UT_24HR
# 0                  -0.200991
# 1                  -0.227582
# 2                  -0.529020
# 3                  -0.063275
# 4                  -0.521024
#
# [5 rows x 3848 columns]

# %%
isolates_list
# Out:
# ['isolate_01',
#  'isolate_02',
#  'isolate_03',
#  'isolate_04',
#  'isolate_05',
#  'isolate_06',
#  'isolate_07',
#  'isolate_08',
#  'isolate_09',
#  'isolate_10',
#  'isolate_11',
#  'isolate_12',
#  'isolate_13',
#  'isolate_14',
#  'isolate_15',
#  'isolate_16',
#  'isolate_17',
#  'isolate_18',
#  'isolate_19',
#  'isolate_20',
#  'isolate_21',
#  'isolate_22',
#  'isolate_23',
#  'isolate_24',
#  'isolate_25',
#  'isolate_26',
#  'isolate_27',
#  'isolate_28',
#  'isolate_29',
#  'isolate_30']

# %%
genes_column_labels_df
# Out:
#                 PF3D7_1360200               PF3D7_1212800  \
# 0      PF3D7_1360200_24HR_DHA      PF3D7_1212800_24HR_DHA
# 1       PF3D7_1360200_24HR_UT       PF3D7_1212800_24HR_UT
# 2       PF3D7_1360200_6HR_DHA       PF3D7_1212800_6HR_DHA
# 3        PF3D7_1360200_6HR_UT        PF3D7_1212800_6HR_UT
# 4  PF3D7_1360200_24HR_6HR_DHA  PF3D7_1212800_24HR_6HR_DHA
# 5     PF3D7_1360200_24_6HR_UT     PF3D7_1212800_24_6HR_UT
# 6    PF3D7_1360200_DHA_UT_6HR    PF3D7_1212800_DHA_UT_6HR
# 7   PF3D7_1360200_DHA_UT_24HR   PF3D7_1212800_DHA_UT_24HR
#
#                 PF3D7_1234600               PF3D7_1406700  \
# 0      PF3D7_1234600_24HR_DHA      PF3D7_1406700_24HR_DHA
# 1       PF3D7_1234600_24HR_UT       PF3D7_1406700_24HR_UT
# 2       PF3D7_1234600_6HR_DHA       PF3D7_1406700_6HR_DHA
# 3        PF3D7_1234600_6HR_UT        PF3D7_1406700_6HR_UT
# 4  PF3D7_1234600_24HR_6HR_DHA  PF3D7_1406700_24HR_6HR_DHA
# 5     PF3D7_1234600_24_6HR_UT     PF3D7_1406700_24_6HR_UT
# 6    PF3D7_1234600_DHA_UT_6HR    PF3D7_1406700_DHA_UT_6HR
# 7   PF3D7_1234600_DHA_UT_24HR   PF3D7_1406700_DHA_UT_24HR
#
#                 PF3D7_1229400               PF3D7_0208200  \
# 0      PF3D7_1229400_24HR_DHA      PF3D7_0208200_24HR_DHA
# 1       PF3D7_1229400_24HR_UT       PF3D7_0208200_24HR_UT
# 2       PF3D7_1229400_6HR_DHA       PF3D7_0208200_6HR_DHA
# 3        PF3D7_1229400_6HR_UT        PF3D7_0208200_6HR_UT
# 4  PF3D7_1229400_24HR_6HR_DHA  PF3D7_0208200_24HR_6HR_DHA
# 5     PF3D7_1229400_24_6HR_UT     PF3D7_0208200_24_6HR_UT
# 6    PF3D7_1229400_DHA_UT_6HR    PF3D7_0208200_DHA_UT_6HR
# 7   PF3D7_1229400_DHA_UT_24HR   PF3D7_0208200_DHA_UT_24HR
#
#                 PF3D7_1220900               PF3D7_0207500  \
# 0      PF3D7_1220900_24HR_DHA      PF3D7_0207500_24HR_DHA
# 1       PF3D7_1220900_24HR_UT       PF3D7_0207500_24HR_UT
# 2       PF3D7_1220900_6HR_DHA       PF3D7_0207500_6HR_DHA
# 3        PF3D7_1220900_6HR_UT        PF3D7_0207500_6HR_UT
# 4  PF3D7_1220900_24HR_6HR_DHA  PF3D7_0207500_24HR_6HR_DHA
# 5     PF3D7_1220900_24_6HR_UT     PF3D7_0207500_24_6HR_UT
# 6    PF3D7_1220900_DHA_UT_6HR    PF3D7_0207500_DHA_UT_6HR
# 7   PF3D7_1220900_DHA_UT_24HR   PF3D7_0207500_DHA_UT_24HR
#
#                 PF3D7_0315100               PF3D7_1340700  ...  \
# 0      PF3D7_0315100_24HR_DHA      PF3D7_1340700_24HR_DHA  ...
# 1       PF3D7_0315100_24HR_UT       PF3D7_1340700_24HR_UT  ...
# 2       PF3D7_0315100_6HR_DHA       PF3D7_1340700_6HR_DHA  ...
# 3        PF3D7_0315100_6HR_UT        PF3D7_1340700_6HR_UT  ...
# 4  PF3D7_0315100_24HR_6HR_DHA  PF3D7_1340700_24HR_6HR_DHA  ...
# 5     PF3D7_0315100_24_6HR_UT     PF3D7_1340700_24_6HR_UT  ...
# 6    PF3D7_0315100_DHA_UT_6HR    PF3D7_1340700_DHA_UT_6HR  ...
# 7   PF3D7_0315100_DHA_UT_24HR   PF3D7_1340700_DHA_UT_24HR  ...
#
#                 PF3D7_1116400               PF3D7_1129100  \
# 0      PF3D7_1116400_24HR_DHA      PF3D7_1129100_24HR_DHA
# 1       PF3D7_1116400_24HR_UT       PF3D7_1129100_24HR_UT
# 2       PF3D7_1116400_6HR_DHA       PF3D7_1129100_6HR_DHA
# 3        PF3D7_1116400_6HR_UT        PF3D7_1129100_6HR_UT
# 4  PF3D7_1116400_24HR_6HR_DHA  PF3D7_1129100_24HR_6HR_DHA
# 5     PF3D7_1116400_24_6HR_UT     PF3D7_1129100_24_6HR_UT
# 6    PF3D7_1116400_DHA_UT_6HR    PF3D7_1129100_DHA_UT_6HR
# 7   PF3D7_1116400_DHA_UT_24HR   PF3D7_1129100_DHA_UT_24HR
#
#                 PF3D7_1418000               PF3D7_0208600  \
# 0      PF3D7_1418000_24HR_DHA      PF3D7_0208600_24HR_DHA
# 1       PF3D7_1418000_24HR_UT       PF3D7_0208600_24HR_UT
# 2       PF3D7_1418000_6HR_DHA       PF3D7_0208600_6HR_DHA
# 3        PF3D7_1418000_6HR_UT        PF3D7_0208600_6HR_UT
# 4  PF3D7_1418000_24HR_6HR_DHA  PF3D7_0208600_24HR_6HR_DHA
# 5     PF3D7_1418000_24_6HR_UT     PF3D7_0208600_24_6HR_UT
# 6    PF3D7_1418000_DHA_UT_6HR    PF3D7_0208600_DHA_UT_6HR
# 7   PF3D7_1418000_DHA_UT_24HR   PF3D7_0208600_DHA_UT_24HR
#
#                 PF3D7_1231100               PF3D7_1330600  \
# 0      PF3D7_1231100_24HR_DHA      PF3D7_1330600_24HR_DHA
# 1       PF3D7_1231100_24HR_UT       PF3D7_1330600_24HR_UT
# 2       PF3D7_1231100_6HR_DHA       PF3D7_1330600_6HR_DHA
# 3        PF3D7_1231100_6HR_UT        PF3D7_1330600_6HR_UT
# 4  PF3D7_1231100_24HR_6HR_DHA  PF3D7_1330600_24HR_6HR_DHA
# 5     PF3D7_1231100_24_6HR_UT     PF3D7_1330600_24_6HR_UT
# 6    PF3D7_1231100_DHA_UT_6HR    PF3D7_1330600_DHA_UT_6HR
# 7   PF3D7_1231100_DHA_UT_24HR   PF3D7_1330600_DHA_UT_24HR
#
#                 PF3D7_1450100               PF3D7_0618500  \
# 0      PF3D7_1450100_24HR_DHA      PF3D7_0618500_24HR_DHA
# 1       PF3D7_1450100_24HR_UT       PF3D7_0618500_24HR_UT
# 2       PF3D7_1450100_6HR_DHA       PF3D7_0618500_6HR_DHA
# 3        PF3D7_1450100_6HR_UT        PF3D7_0618500_6HR_UT
# 4  PF3D7_1450100_24HR_6HR_DHA  PF3D7_0618500_24HR_6HR_DHA
# 5     PF3D7_1450100_24_6HR_UT     PF3D7_0618500_24_6HR_UT
# 6    PF3D7_1450100_DHA_UT_6HR    PF3D7_0618500_DHA_UT_6HR
# 7   PF3D7_1450100_DHA_UT_24HR   PF3D7_0618500_DHA_UT_24HR
#
#                 PF3D7_0628200               PF3D7_1368700
# 0      PF3D7_0628200_24HR_DHA      PF3D7_1368700_24HR_DHA
# 1       PF3D7_0628200_24HR_UT       PF3D7_1368700_24HR_UT
# 2       PF3D7_0628200_6HR_DHA       PF3D7_1368700_6HR_DHA
# 3        PF3D7_0628200_6HR_UT        PF3D7_1368700_6HR_UT
# 4  PF3D7_0628200_24HR_6HR_DHA  PF3D7_1368700_24HR_6HR_DHA
# 5     PF3D7_0628200_24_6HR_UT     PF3D7_1368700_24_6HR_UT
# 6    PF3D7_0628200_DHA_UT_6HR    PF3D7_1368700_DHA_UT_6HR
# 7   PF3D7_0628200_DHA_UT_24HR   PF3D7_1368700_DHA_UT_24HR
#
# [8 rows x 481 columns]

# %% [markdown]
# ## 2. Hacer modelo lineal de manera incremental (un gen con sus 8 valores a la vez)
#
# ### Isolates for validation
# * isolate_07
# * isolate_27
# * isolate_18
# * isolate_11
# * isolate_16
#
# ### Models to try out
# * [LASSO (R2)](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Lasso.html)
# * [Linear Regression (RMSE)](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# ### 2.1 Create the functions

# %%
#Global variables
#val_isolates
#genes_dict
val_isolates=['isolate_07','isolate_11','isolate_16','isolate_18','isolate_27']

# %%
def getGenesColumnLabels(genes):
    genes_list=[]
    for gene in genes:
        genes_list=list(genes_column_labels_df[gene])
    return genes_list

# %%
def findTrainIsolates(val_isolates,df):
    train_isolates=list(set(df.index)-set(val_isolates))
    train_isolates.sort()
    return train_isolates

# %%
def filterDfByIsolates(isolates,df):
    filtered_df=df.loc[isolates]
    return filtered_df

# %%
def filterDfByGenes(genes,df):
    genes_to_filter=getGenesColumnLabels(genes)
    filtered_df=df[genes_to_filter]
    return filtered_df

# %%
def trainModel(genes,val_isolates,dfx,dfy):
    train_isolates=findTrainIsolates(val_isolates,dfx)
    
    X=filterDfByIsolates(train_isolates,dfx)
    X=filterDfByGenes(genes,X)
    
    y=filterDfByIsolates(train_isolates,dfy)
    
    model=LinearRegression().fit(X.values,y.values)
    
    X_val=filterDfByIsolates(val_isolates,dfx)
    X_val=filterDfByGenes(genes,X_val)
    
    y_val=filterDfByIsolates(val_isolates,dfy).values
    
    score=model.score(X_val,y_val)
    
    return score

# %%
selected_genes=[]
selected_scores=[0]
N=5
for i in range(N):
    best_gene_so_far=''
    best_score_so_far=selected_scores[-1]
    
    for gene in genes_list:
        
        if gene not in selected_genes:
            genes_to_use=selected_genes+[gene]
            
            model_score=trainModel(genes_to_use,val_isolates,train,IC50)
            
            if model_score > best_score_so_far:
                best_score_so_far=model_score
                best_gene_so_far=gene

    
    if best_score_so_far>selected_scores[-1]:
        selected_genes.append(best_gene_so_far)
        selected_scores.append(best_score_so_far)

# %%
#N=100
x=np.arange(len(selected_scores))
y=selected_scores
plt.plot(x,y)
plt.xticks(x,selected_genes,rotation='vertical')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
selected_scores
# Out:
# [0, 0.7232934274782723]

# %% [markdown]
# ### 2.2 Try the model with the three selected genes

# %%
selected_genes=['PF3D7_0730200','PF3D7_1341600','PF3D7_1426200']

# %%
def tryModel(genes,val_isolates,dfx,dfy):
    model_info={}
    
    train_isolates=findTrainIsolates(val_isolates,dfx)
    
    X=filterDfByIsolates(train_isolates,dfx)
    X=filterDfByGenes(genes,X)
    
    y=filterDfByIsolates(train_isolates,dfy)
    
    model=LinearRegression().fit(X.values,y.values)
    
    X_val=filterDfByIsolates(val_isolates,dfx)
    X_val=filterDfByGenes(genes,X_val)
    
    y_val=filterDfByIsolates(val_isolates,dfy).values
    
    y_pred=model.predict(X_val)
    
    score=model.score(X_val,y_val)
    
    model_info['y']=y.values
    model_info['y_val']=y_val
    model_info['X']=X.values
    model_info['X_val']=X_val
    model_info['y_pred']=y_pred
    model_info['score']=score
    return model_info

# %%
#Try the model with the first selected gene
gene=['PF3D7_0730200']

# %%
try_model=tryModel(gene,val_isolates,train,IC50)

# %%
y=[try_model['y_val'][i][0] for i in range(len(try_model['y_val']))]
y_pred=[try_model['y_pred'][i][0] for i in range(len(try_model['y_pred']))]

# %%
plt.plot(y,y_pred)

# %% [markdown]
# ### 2.3 Train the model with all the isolates and only the three selected genes

# %%
selected_genes
# Out:
# ['PF3D7_0730200', 'PF3D7_1341600', 'PF3D7_1426200']

# %%
selected_train=train[getGenesColumnLabels(selected_genes)]
selected_train.head()
# Out:
#             PF3D7_1426200_24HR_DHA  PF3D7_1426200_24HR_UT  \
# isolate_01               -0.128304               0.715598
# isolate_02                0.240229               0.013204
# isolate_03                0.345671              -0.097277
# isolate_04                0.017374               0.456434
# isolate_05                0.652695              -0.293320
#
#             PF3D7_1426200_6HR_DHA  PF3D7_1426200_6HR_UT  \
# isolate_01               0.011499              0.981056
# isolate_02               0.108668              0.220774
# isolate_03               0.413015             -0.258171
# isolate_04              -0.186565             -0.109549
# isolate_05               0.351933              0.334961
#
#             PF3D7_1426200_24HR_6HR_DHA  PF3D7_1426200_24_6HR_UT  \
# isolate_01                   -0.139804                -0.265458
# isolate_02                    0.131561                -0.207570
# isolate_03                   -0.067345                 0.160894
# isolate_04                    0.203938                 0.565983
# isolate_05                    0.300762                -0.628281
#
#             PF3D7_1426200_DHA_UT_6HR  PF3D7_1426200_DHA_UT_24HR
# isolate_01                 -0.969557                  -0.843902
# isolate_02                 -0.112106                   0.227026
# isolate_03                  0.671187                   0.442948
# isolate_04                 -0.077016                  -0.439060
# isolate_05                  0.016973                   0.946015

# %%
X=selected_train
y=IC50

model=LinearRegression().fit(X.values,y.values)

# %% [markdown]
# ### 2.4 Save the model

# %%
from sklearn.externals import joblib
# Output a pickle file for the model
joblib.dump(model, 'model1_140719.pkl')
# Out:
# ['model1_140719.pkl']

# %% [markdown]
# ## 3. Use the model on the test data

# %%
test.head()
# Out:
#             PF3D7_1360200_24HR_DHA  PF3D7_1360200_24HR_UT  \
# isolate_31               -0.174775              -0.295609
# isolate_32                0.399533               0.146867
# isolate_33               -0.176645              -0.544585
# isolate_34               -0.417563              -0.403714
# isolate_35               -0.479479              -0.105337
#
#             PF3D7_1360200_6HR_DHA  PF3D7_1360200_6HR_UT  \
# isolate_31              -0.416325              0.298822
# isolate_32               0.324318              0.315899
# isolate_33               0.019547             -0.417121
# isolate_34               0.338701              0.404703
# isolate_35               0.544339             -0.924440
#
#             PF3D7_1212800_24HR_DHA  PF3D7_1212800_24HR_UT  \
# isolate_31                0.128111               0.561929
# isolate_32                0.066858               0.027401
# isolate_33                0.138302               0.526993
# isolate_34                0.301630               0.463055
# isolate_35                0.221467               0.114849
#
#             PF3D7_1212800_6HR_DHA  PF3D7_1212800_6HR_UT  \
# isolate_31               0.345033              0.056966
# isolate_32               0.067937             -0.464352
# isolate_33               0.138940             -0.084193
# isolate_34               0.053077              0.119237
# isolate_35              -0.033903              0.292947
#
#             PF3D7_1234600_24HR_DHA  PF3D7_1234600_24HR_UT  ...  \
# isolate_31               -0.194875              -0.170907  ...
# isolate_32               -0.138635              -0.733134  ...
# isolate_33               -0.051677              -0.083284  ...
# isolate_34               -0.006026               0.184238  ...
# isolate_35                0.130474              -0.274636  ...
#
#             PF3D7_0618500_DHA_UT_6HR  PF3D7_0618500_DHA_UT_24HR  \
# isolate_31                  0.344871                  -0.621592
# isolate_32                  0.047088                   0.380829
# isolate_33                  0.306211                  -0.093699
# isolate_34                  1.108617                   0.198459
# isolate_35                 -0.703833                   0.573340
#
#             PF3D7_0628200_24HR_6HR_DHA  PF3D7_0628200_24_6HR_UT  \
# isolate_31                   -0.126831                -0.194757
# isolate_32                    0.172600                 0.018954
# isolate_33                   -0.119335                 0.023164
# isolate_34                   -0.302420                -0.342440
# isolate_35                   -0.224813                 0.068472
#
#             PF3D7_0628200_DHA_UT_6HR  PF3D7_0628200_DHA_UT_24HR  \
# isolate_31                 -0.121074                  -0.053148
# isolate_32                 -0.089144                   0.064502
# isolate_33                  0.169706                   0.027207
# isolate_34                  0.042755                   0.082776
# isolate_35                  0.060340                  -0.232946
#
#             PF3D7_1368700_24HR_6HR_DHA  PF3D7_1368700_24_6HR_UT  \
# isolate_31                   -0.865734                -0.955845
# isolate_32                   -0.213451                 0.608781
# isolate_33                   -0.484834                 0.364730
# isolate_34                    0.251723                -0.637584
# isolate_35                   -0.898682                 0.426429
#
#             PF3D7_1368700_DHA_UT_6HR  PF3D7_1368700_DHA_UT_24HR
# isolate_31                 -0.291102                  -0.200991
# isolate_32                  0.594650                  -0.227582
# isolate_33                  0.320544                  -0.529020
# isolate_34                 -0.952582                  -0.063275
# isolate_35                  0.804087                  -0.521024
#
# [5 rows x 3848 columns]

# %% [markdown]
# ### 3.1 Make the IC50 predictions

# %%
#Load the model
model_load = joblib.load('../models/model1_140719.pkl')

# %%
selected_test=test[getGenesColumnLabels(selected_genes)]
selected_test.head()
# Out:
#             PF3D7_1426200_24HR_DHA  PF3D7_1426200_24HR_UT  \
# isolate_31                0.329245               0.178702
# isolate_32                0.645354               0.735466
# isolate_33                0.018793               0.287341
# isolate_34                0.170532               0.075933
# isolate_35                0.186138               0.498472
#
#             PF3D7_1426200_6HR_DHA  PF3D7_1426200_6HR_UT  \
# isolate_31               0.371113              0.707257
# isolate_32               0.810575              0.376228
# isolate_33               0.440818             -0.049872
# isolate_34               0.375788              0.925295
# isolate_35               1.244600             -0.329952
#
#             PF3D7_1426200_24HR_6HR_DHA  PF3D7_1426200_24_6HR_UT  \
# isolate_31                   -0.041868                -0.528555
# isolate_32                   -0.165220                 0.359238
# isolate_33                   -0.422026                 0.337213
# isolate_34                   -0.205256                -0.849361
# isolate_35                   -1.058462                 0.828424
#
#             PF3D7_1426200_DHA_UT_6HR  PF3D7_1426200_DHA_UT_24HR
# isolate_31                 -0.336144                   0.150544
# isolate_32                  0.434347                  -0.090111
# isolate_33                  0.490690                  -0.268549
# isolate_34                 -0.549507                   0.094599
# isolate_35                  1.574552                  -0.312334

# %%
X_test=selected_test
X_test.shape
# Out:
# (25, 8)

# %%
IC50_pred=model_load.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-a7eb1d90e240> in <module>
# ----> 1 IC50_pred=model_load.predict(X_test)
#
# C:\Users\Public\Miniconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     211             Returns predicted values.
#     212         """
# --> 213         return self._decision_function(X)
#     214
#     215     _preprocess_data = staticmethod(_preprocess_data)
#
# C:\Users\Public\Miniconda3\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     196         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     197         return safe_sparse_dot(X, self.coef_.T,
# --> 198                                dense_output=True) + self.intercept_
#     199
#     200     def predict(self, X):
#
# C:\Users\Public\Miniconda3\lib\site-packages\sklearn\utils\extmath.py in safe_sparse_dot(a, b, dense_output)
#     171         return ret
#     172     else:
# --> 173         return np.dot(a, b)
#     174
#     175
#
# ValueError: shapes (25,8) and (24,1) not aligned: 8 (dim 1) != 24 (dim 0)

# %%
temp_list=[]
for value in ic50_pred:
    temp_list.append(value)
ic50_pred=temp_list

# %%
submission=pd.DataFrame({'Isolate':isolates_list_test,'Predicted_IC50':ic50_pred})

# %%
submission.head()

# %%
submission.to_csv('../submissions/lylat_SubCh1_model1_140719.txt', sep='\t',index=None)
